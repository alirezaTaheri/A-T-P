# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
from backtrader.indicators import ExponentialMovingAverage
# from talib import STOCH
fromdate = pd.Timestamp('2017-03-17')
todate = pd.Timestamp('2019-12-17')
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('macd_period_short', 12),
        ('macd_period_long', 26),
        ('macd_signal_period', 9),
        ('printlog', False)
    )
    def log(self, txt, dt=None, doprint=False):
        ''' Logging function for this strategy'''
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.volume = self.datas[0].volume
        self.order = None
#         self.sma = bt.indicators.SimpleMovingAverage(
#             self.datas[0], period=self.params.maperiod)

#         macd = ExponentialMovingAverage(self.datas[0], self.params.macd_period_1) - ExponentialMovingAverage(self.datas[0], self.params.macd_period_2)
#         signal = ExponentialMovingAverage(macd, self.params.macd_signal_period)
        self.long_ema = bt.indicators.ExponentialMovingAverage(self.datas[0], period = self.params.macd_period_long, plot=False)
        self.short_ema = bt.indicators.ExponentialMovingAverage(self.datas[0], period = self.params.macd_period_short, plot=False)
        self.macd = self.short_ema - self.long_ema
        self.signal = bt.indicators.ExponentialMovingAverage(self.macd, period = self.params.macd_signal_period, plot=False)
        self.rsi = bt.indicators.RSI(self.datas[0], plot=False, subplot=True, plothlines=[20,80])
        self.bollinger = bt.indicators.BollingerBands(self.datas[0], plot=False)
        self.stoch = bt.talib.STOCH(self.data.high, self.data.low, self.data.close, plot=False)
#         plotlines = dict(
#         buy=dict(marker='^', markersize=8.0, color='lime', fillstyle='full', plot=True),
#         sell=dict(marker='v', markersize=8.0, color='red', fillstyle='full', plot=True)
#         )
#         self.bollinger.plotinfo.plotname= 'abcdefg'
#         self.bollinger.plotinfo.plot = True
#         print(bt.talib.STOCH.__doc__)
#         fastk_period=14, slowk_period=3, slowd_period=3)
#         self.sma = bt.talib.SMA(self.data, timeperiod=14)
#         d0 = bt.ind.EMA(self.data.high, period=14)
#         d1 = bt.ind.EMA(self.data.low, period=14)
#         d2 = bt.ind.EMA(self.data.close, period=14)

#         Stochastic_Generic(d0, d1, d2)  # customized stochastic

#         # These two have generate the same results
#         Stochastic_Generic(self.data.high, self.data.low, self.data.close)
#         bt.ind.Stochastic(self.data)
#                              , fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
#         bt.indicators.ExponentialMovingAverage(self.datas[0], period=25)
#         bt.indicators.WeightedMovingAverage(self.datas[0], period=25,
#                                             subplot=True)
#         bt.indicators.StochasticSlow(self.datas[0])
#         bt.indicators.MACDHisto(self.datas[0])
#         rsi = bt.indicators.RSI(self.datas[0])
#         bt.indicators.SmoothedMovingAverage(rsi, period=10)
#         bt.indicators.ATR(self.datas[0], plot=False)
    
    def next(self):
        if not checkDate(fromdate, self.data.datetime.date()):
            return
        print('------------------------------------------------', len(self))
        self.log('Close: %.2f' % self.dataclose[0])
#         print("&&&&&&&&&&&", type(self.data.datetime))
#         print("Volume: " , self.volume.array)
        print("macd", self.macd[0],"  Signal", self.signal[0])
        print("rsi", self.rsi[0])
        print("short EMA", self.short_ema[0])
        print("long EMA", self.long_ema[0])
        print("Bollinger Top", self.bollinger.top[0], "  Bollinger Bottom", self.bollinger.bot[0])
        print("Stochastic K", self.stoch.slowk[0], '  Stochastic D:' , self.stoch.slowd[0])
        
#         print("^^^^^^",self.dataclose.array[len(self)-2:len(self)+3])
#         print(self.getposition(data, self.broker))
        value = checkAll(self.macd, self.signal, self.short_ema, self.long_ema, self.rsi, self.bollinger,
                 self.dataclose, self.stoch, self.data.datetime.date())
        cash = self.broker.getcash()
        portfolioValue = self.broker.getvalue()
        fundvalue = self.broker.fundvalue
        fundshares = self.broker.fundshares
#         aa = self.broker.get_fundshares()
#         print("=================", aa)
#         print(cash, portfolioValue, fundvalue, fundshares)
#         if value>= 70:
#             self.buy(size=self.broker.getcash()//self.dataclose[0])
#         if self.position and value < 20:
#             self.close()
        
#         self.line[0] = value
#         if len(self) == 35:
#             self.order = self.buy(size=10)
#         elif len(self) == 210:
#             self.order = self.sell(size=10)
#         print("SMA: " , self.sma[0])
#         print("POS", self.position)
#         if self.position:
#             print("lne is :" , len(self), self.bar_executed)

#         if self.order:
#             return
        
#         if not self.position:
#             if value > 28:
#                 '''BUY SIGNAL'''
# #                 self.log("Buy Signal: %.2f" % self.dataclose[0])
#                 self.log('Close: %.2f' % self.dataclose[0])
#                 self.order = self.buy()
#         else :
#             if value < 7:
# #                 self.log("SELL Signal: %.2f" % self.dataclose[0])
#                 self.log('Close: %.2f' % self.dataclose[0])
#                 self.order = self.sell()
        
            
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        if order.status is order.Completed:
            if order.isbuy():
                pass
#                 print("***BUY EXECUTED")
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Size: %2f , Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.size,
                     order.executed.comm))
            else:
                pass
#                 print("!!!SELL EXECUTED")
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Size: %2f , Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.size,
                          order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            pass
#             self.log('Order Canceled/Margin/Rejected')
        self.order = None
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
        
#     def notify_cashvalue(self, cash, value):
#         print("CCCCCCCC", cash,"  /  ", value)
        
#     def notify_fund(self, cash, value, fundvalue, shares):
#         print("pppppppp", cash,"  /  ",value, fundvalue,'  /  ', shares)
#     def stop(self):
#         self.log('(MA Period %2d) Ending Value %.2f' %
#                  (self.params.maperiod, self.broker.getvalue()), doprint=True)
#     def prenext(self):
#         print('prenext:: current period:', len(self))

#     def nextstart(self):
#         print('nextstart:: current period:', len(self))
        # emulate default behavior ... call next
#         self.next()
        
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro(stdstats=True)

    # Add a strategy
#     cerebro.optstrategy(TestStrategy, maperiod=range(10, 31))
    cerebro.addstrategy(TestStrategy, printlog=True)
#     cerebro.optstrategy(TestStrategy, printlog=True, macd_period_short=range(),macd_period_long=range(), macd_signal_period=range())
    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, '../../../../../../../pythonprojects/IranKhodro.csv')
    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=fromdate,
        # Do not pass values before this date
        todate=todate,
        # Do not pass values after this date
        reverse=False,
        adjvolume=False,
        adjclose=False,
        r=False
    )

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000000)
    cerebro.broker.setcommission(commission=0)
    
    cerebro.addsizer(bt.sizers.FixedSize, stake=1)
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run(runonce=False)
#     %matplotlib inline
#     cerebro.plot()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 1000000.00
# ------------------------------------------------ 459
# 2019-03-17, Close: 2815.00
# macd -7.739864982321251   Signal -14.32909311400157
# rsi 57.32944250858962
# short EMA 2719.3397080438062
# long EMA 2727.0795730261275
# Bollinger Top 2836.4919061802475   Bollinger Bottom 2614.108093819753
# Stochastic K 62.82218944608326   Stochastic D: 45.93877885470806
# today Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff:  -7.739864982321251
# 0 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# @STOCH, stoch comparison: 0
# 2018-09-17 00:00:00 2019-03-17 00:00:00
# 2018-03-17 00:00:00 2018-09-16 00:00:00
# 2017-03-18 00:00:00 2018-03-14 00:00:00
# Current Close:  2815.0
# Check between 2401.0    3629.0
# Check between 2015.0    2762.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-17 /////////////////////
# RSI 7.556852497136793
# MACD 10
# EMA DIFF 0
# Bollinger Bands 1.9328660617984283
# Stochastic Value 3.168258650559535
# CF Value 7.570788738948348
# ##################################### Results =  30.228765948443108 %
# ------------------------------------------------ 460
# 2019-03-18, Close: 2839.00
# macd 2.3790087051829687   Signal -10.987472750164661
# rsi 58.979362139106016
# short EMA 2737.7489837293747
# long EMA 2735.3699750241917
# Bollinger Top 2853.1844423008693   Bollinger Bottom 2610.7155576991304
# Stochastic K 71.62847774877444   Stochastic D: 58.70382699318842
# today Short EMA: 2737.7489837293747 Long EMA: 2735.3699750241917 Diff:  2.3790087051829687
# -1 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# -1 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# @STOCH, stoch comparison: 0
# 2018-09-18 00:00:00 2019-03-18 00:00:00
# 2018-03-18 00:00:00 2018-09-17 00:00:00
# 2017-03-18 00:00:00 2018-03-17 00:00:00
# Current Close:  2839.0
# Check between 2401.0    3629.0
# Check between 2015.0    2898.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-18 /////////////////////
# RSI 7.0068792869646614
# MACD 10
# EMA DIFF 2.5
# Bollinger Bands 1.170001035321917
# Stochastic Value 1.9102174644607945
# CF Value 7.739303473869435
# ##################################### Results =  30.326401260616805 %
# ------------------------------------------------ 461
# 2019-03-19, Close: 2884.00
# macd 13.869533574820707   Signal -6.016071485167588
# rsi 61.95016101893359
# short EMA 2760.2491400787017
# long EMA 2746.379606503881
# Bollinger Top 2875.231232816417   Bollinger Bottom 2600.1687671835825
# Stochastic K 81.24231523871812   Stochastic D: 71.89766081119194
# today Short EMA: 2760.2491400787017 Long EMA: 2746.379606503881 Diff:  13.869533574820707
# -1 th Day Short EMA: 2737.7489837293747 Long EMA: 2735.3699750241917 Diff 2.3790087051829687
# -2 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# -2 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# @STOCH, stoch comparison: 0
# 2018-09-22 00:00:00 2019-03-19 00:00:00
# 2018-03-19 00:00:00 2018-09-18 00:00:00
# 2017-03-25 00:00:00 2018-03-18 00:00:00
# Current Close:  2884.0
# Check between 2401.0    3629.0
# Check between 2015.0    3042.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-19 /////////////////////
# RSI 6.016612993688803
# MACD 10
# EMA DIFF 5.0
# Bollinger Bands 0
# Stochastic Value 0.536812108754555
# CF Value 7.787486129505673
# ##################################### Results =  29.34091123194903 %
# ------------------------------------------------ 462
# 2019-03-25, Close: 2960.00
# macd 28.776702249610025   Signal 0.9424832617879346
# rsi 66.37879581751525
# short EMA 2790.9800416050552
# long EMA 2762.203339355445
# Bollinger Top 2917.4596047093733   Bollinger Bottom 2584.5403952906267
# Stochastic K 79.41084410277772   Stochastic D: 77.42721236342344
# today Short EMA: 2790.9800416050552 Long EMA: 2762.203339355445 Diff:  28.776702249610025
# -1 th Day Short EMA: 2760.2491400787017 Long EMA: 2746.379606503881 Diff 13.869533574820707
# -2 th Day Short EMA: 2737.7489837293747 Long EMA: 2735.3699750241917 Diff 2.3790087051829687
# -3 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# -3 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# @STOCH, stoch comparison: 0
# 2018-09-25 00:00:00 2019-03-25 00:00:00
# 2018-03-25 00:00:00 2018-09-24 00:00:00
# 2017-03-25 00:00:00 2018-03-19 00:00:00
# Current Close:  2960.0
# Check between 2401.0    3629.0
# Check between 2015.0    3241.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-25 /////////////////////
# RSI 4.540401394161583
# MACD 10
# EMA DIFF 7.5
# Bollinger Bands 0
# Stochastic Value 0.7984508424603263
# CF Value 7.367472661386822
# ##################################### Results =  30.20632489800873 %
# ------------------------------------------------ 463
# 2019-03-26, Close: 3108.00
# macd 51.93443608598773   Signal 11.140873826627894
# rsi 72.97526204134061
# short EMA 2839.752342896585
# long EMA 2787.8179068105974
# Bollinger Top 2992.34752588468   Bollinger Bottom 2538.65247411532
# Stochastic K 89.12307431860505   Stochastic D: 83.25874455336697
# today Short EMA: 2839.752342896585 Long EMA: 2787.8179068105974 Diff:  51.93443608598773
# -1 th Day Short EMA: 2790.9800416050552 Long EMA: 2762.203339355445 Diff 28.776702249610025
# -2 th Day Short EMA: 2760.2491400787017 Long EMA: 2746.379606503881 Diff 13.869533574820707
# -3 th Day Short EMA: 2737.7489837293747 Long EMA: 2735.3699750241917 Diff 2.3790087051829687
# -4 th Day Short EMA: 2719.3397080438062 Long EMA: 2727.0795730261275 Diff -7.739864982321251
# @STOCH, stoch comparison: 0
# 2018-09-26 00:00:00 2019-03-26 00:00:00
# 2018-03-26 00:00:00 2018-09-25 00:00:00
# 2017-03-26 00:00:00 2018-03-25 00:00:00
# Current Close:  3108.0
# Check between 2401.0    3629.0
# Check between 2015.0    3241.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-26 /////////////////////
# RSI 2.34157931955313
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 4.677326429506395
# ##################################### Results =  27.018905749059524 %
# ------------------------------------------------ 464
# 2019-03-27, Close: 3227.00
# macd 78.97899181436378   Signal 24.70849742417507
# rsi 76.89976303382684
# short EMA 2899.3289055278797
# long EMA 2820.349913713516
# Bollinger Top 3085.878660610725   Bollinger Bottom 2482.3213393892747
# Stochastic K 91.19939306159044   Stochastic D: 86.5777704943244
# today Short EMA: 2899.3289055278797 Long EMA: 2820.349913713516 Diff:  78.97899181436378
# -1 th Day Short EMA: 2839.752342896585 Long EMA: 2787.8179068105974 Diff 51.93443608598773
# -2 th Day Short EMA: 2790.9800416050552 Long EMA: 2762.203339355445 Diff 28.776702249610025
# -3 th Day Short EMA: 2760.2491400787017 Long EMA: 2746.379606503881 Diff 13.869533574820707
# -4 th Day Short EMA: 2737.7489837293747 Long EMA: 2735.3699750241917 Diff 2.3790087051829687
# @STOCH, stoch comparison: 0
# 2018-09-29 00:00:00 2019-03-27 00:00:00
# 2018-03-27 00:00:00 2018-09-26 00:00:00
# 2017-03-27 00:00:00 2018-03-26 00:00:00
# Current Close:  3227.0
# Check between 2401.0    3629.0
# Check between 2015.0    3241.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-27 /////////////////////
# RSI 1.0334123220577212
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 2.698827255288509
# ##################################### Results =  23.73223957734623 %
# ------------------------------------------------ 465
# 2019-03-30, Close: 3334.00
# macd 107.80331334725815   Signal 41.32746060879169
# rsi 79.74763348639743
# short EMA 2966.2013816005137
# long EMA 2858.3980682532556
# Bollinger Top 3195.6194360293557   Bollinger Bottom 2424.4805639706447
# Stochastic K 94.15375350334699   Stochastic D: 91.4920736278475
# today Short EMA: 2966.2013816005137 Long EMA: 2858.3980682532556 Diff:  107.80331334725815
# -1 th Day Short EMA: 2899.3289055278797 Long EMA: 2820.349913713516 Diff 78.97899181436378
# -2 th Day Short EMA: 2839.752342896585 Long EMA: 2787.8179068105974 Diff 51.93443608598773
# -3 th Day Short EMA: 2790.9800416050552 Long EMA: 2762.203339355445 Diff 28.776702249610025
# -4 th Day Short EMA: 2760.2491400787017 Long EMA: 2746.379606503881 Diff 13.869533574820707
# @STOCH, stoch comparison: 0
# 2018-09-30 00:00:00 2019-03-30 00:00:00
# 2018-04-03 00:00:00 2018-09-29 00:00:00
# 2017-04-03 00:00:00 2018-03-28 00:00:00
# Current Close:  3334.0
# Check between 2401.0    3629.0
# Check between 2015.0    3305.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-30 /////////////////////
# RSI 0.08412217120085685
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 1.9218241042345277
# ##################################### Results =  22.005946275435385 %
# ------------------------------------------------ 466
# 2019-03-31, Close: 3478.00
# macd 140.64512294314727   Signal 61.19099307566281
# rsi 82.81770423008572
# short EMA 3044.9396305850505
# long EMA 2904.2945076419032
# Bollinger Top 3328.088805179259   Bollinger Bottom 2367.611194820741
# Stochastic K 92.97095780442226   Stochastic D: 92.77470145645323
# today Short EMA: 3044.9396305850505 Long EMA: 2904.2945076419032 Diff:  140.64512294314727
# -1 th Day Short EMA: 2966.2013816005137 Long EMA: 2858.3980682532556 Diff 107.80331334725815
# -2 th Day Short EMA: 2899.3289055278797 Long EMA: 2820.349913713516 Diff 78.97899181436378
# -3 th Day Short EMA: 2839.752342896585 Long EMA: 2787.8179068105974 Diff 51.93443608598773
# -4 th Day Short EMA: 2790.9800416050552 Long EMA: 2762.203339355445 Diff 28.776702249610025
# @STOCH, stoch comparison: 0
# 2018-09-30 00:00:00 2019-03-31 00:00:00
# 2018-04-03 00:00:00 2018-09-29 00:00:00
# 2017-04-03 00:00:00 2018-03-28 00:00:00
# Current Close:  3478.0
# Check between 2401.0    3629.0
# Check between 2015.0    3305.0
# Check between 2356.0    3196.0
# //////////////// 2019-03-31 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 0.9837133550488595
# ##################################### Results =  20.98371335504886 %
# ------------------------------------------------ 467
# 2019-04-06, Close: 3623.00
# macd 176.3400435901467   Signal 84.22080317855959
# rsi 85.24346126893876
# short EMA 3133.8719951104276
# long EMA 2957.531951520281
# Bollinger Top 3475.531412821525   Bollinger Bottom 2310.768587178475
# Stochastic K 93.72124768915046   Stochastic D: 93.6153196656399
# today Short EMA: 3133.8719951104276 Long EMA: 2957.531951520281 Diff:  176.3400435901467
# -1 th Day Short EMA: 3044.9396305850505 Long EMA: 2904.2945076419032 Diff 140.64512294314727
# -2 th Day Short EMA: 2966.2013816005137 Long EMA: 2858.3980682532556 Diff 107.80331334725815
# -3 th Day Short EMA: 2899.3289055278797 Long EMA: 2820.349913713516 Diff 78.97899181436378
# -4 th Day Short EMA: 2839.752342896585 Long EMA: 2787.8179068105974 Diff 51.93443608598773
# @STOCH, stoch comparison: 0
# 2018-10-06 00:00:00 2019-04-06 00:00:00
# 2018-04-07 00:00:00 2018-10-03 00:00:00
# 2017-04-08 00:00:00 2018-04-04 00:00:00
# Current Close:  3623.0
# Check between 2401.0    3623.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-06 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 0.02602230483271306
# ##################################### Results =  20.026022304832715 %
# ------------------------------------------------ 468
# 2019-04-07, Close: 3796.00
# macd 216.0971461644035   Signal 110.59607177572838
# rsi 87.50924115717595
# short EMA 3235.7378420165155
# long EMA 3019.640695852112
# Bollinger Top 3642.50287262571   Bollinger Bottom 2254.3971273742895
# Stochastic K 96.70906397944138   Stochastic D: 94.46708982433803
# today Short EMA: 3235.7378420165155 Long EMA: 3019.640695852112 Diff:  216.0971461644035
# -1 th Day Short EMA: 3133.8719951104276 Long EMA: 2957.531951520281 Diff 176.3400435901467
# -2 th Day Short EMA: 3044.9396305850505 Long EMA: 2904.2945076419032 Diff 140.64512294314727
# -3 th Day Short EMA: 2966.2013816005137 Long EMA: 2858.3980682532556 Diff 107.80331334725815
# -4 th Day Short EMA: 2899.3289055278797 Long EMA: 2820.349913713516 Diff 78.97899181436378
# @STOCH, stoch comparison: 0
# 2018-10-07 00:00:00 2019-04-07 00:00:00
# 2018-04-07 00:00:00 2018-10-06 00:00:00
# 2017-04-08 00:00:00 2018-04-04 00:00:00
# Current Close:  3796.0
# Check between 2401.0    3796.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-07 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 0.0
# ##################################### Results =  20.0 %
# ------------------------------------------------ 469
# 2019-04-08, Close: 3861.00
# macd 249.9684128973463   Signal 138.47054000005198
# rsi 88.23987073215378
# short EMA 3331.9320201678206
# long EMA 3081.9636072704743
# Bollinger Top 3795.244387346841   Bollinger Bottom 2218.455612653159
# Stochastic K 93.3607328068137   Stochastic D: 94.59701482513519
# today Short EMA: 3331.9320201678206 Long EMA: 3081.9636072704743 Diff:  249.9684128973463
# -1 th Day Short EMA: 3235.7378420165155 Long EMA: 3019.640695852112 Diff 216.0971461644035
# -2 th Day Short EMA: 3133.8719951104276 Long EMA: 2957.531951520281 Diff 176.3400435901467
# -3 th Day Short EMA: 3044.9396305850505 Long EMA: 2904.2945076419032 Diff 140.64512294314727
# -4 th Day Short EMA: 2966.2013816005137 Long EMA: 2858.3980682532556 Diff 107.80331334725815
# @STOCH, stoch comparison: 10
# 2018-10-08 00:00:00 2019-04-08 00:00:00
# 2018-04-08 00:00:00 2018-10-07 00:00:00
# 2017-04-08 00:00:00 2018-04-07 00:00:00
# Current Close:  3861.0
# Check between 2401.0    3861.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-08 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 10
# CF Value 0.0
# ##################################### Results =  30.0 %
# ------------------------------------------------ 470
# 2019-04-09, Close: 3805.00
# macd 269.1898507889987   Signal 164.61440215784134
# rsi 83.69752294448273
# short EMA 3404.711709372771
# long EMA 3135.5218585837724
# Bollinger Top 3909.684693258084   Bollinger Bottom 2213.715306741916
# Stochastic K 85.7961911024048   Stochastic D: 91.95532929621997
# today Short EMA: 3404.711709372771 Long EMA: 3135.5218585837724 Diff:  269.1898507889987
# -1 th Day Short EMA: 3331.9320201678206 Long EMA: 3081.9636072704743 Diff 249.9684128973463
# -2 th Day Short EMA: 3235.7378420165155 Long EMA: 3019.640695852112 Diff 216.0971461644035
# -3 th Day Short EMA: 3133.8719951104276 Long EMA: 2957.531951520281 Diff 176.3400435901467
# -4 th Day Short EMA: 3044.9396305850505 Long EMA: 2904.2945076419032 Diff 140.64512294314727
# @STOCH, stoch comparison: 10
# 2018-10-09 00:00:00 2019-04-09 00:00:00
# 2018-04-09 00:00:00 2018-10-08 00:00:00
# 2017-04-09 00:00:00 2018-04-08 00:00:00
# Current Close:  3805.0
# Check between 2401.0    3861.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-09 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 1.2345115907206967
# Stochastic Value 10
# CF Value 0.3068493150684928
# ##################################### Results =  31.54136090578919 %
# ------------------------------------------------ 471
# 2019-04-10, Close: 3880.00
# macd 287.1645972763163   Signal 189.12444118153633
# rsi 84.82426178641185
# short EMA 3477.8329848538833
# long EMA 3190.668387577567
# Bollinger Top 4020.494069475903   Bollinger Bottom 2224.705930524097
# Stochastic K 80.08792453068799   Stochastic D: 86.41494947996883
# today Short EMA: 3477.8329848538833 Long EMA: 3190.668387577567 Diff:  287.1645972763163
# -1 th Day Short EMA: 3404.711709372771 Long EMA: 3135.5218585837724 Diff 269.1898507889987
# -2 th Day Short EMA: 3331.9320201678206 Long EMA: 3081.9636072704743 Diff 249.9684128973463
# -3 th Day Short EMA: 3235.7378420165155 Long EMA: 3019.640695852112 Diff 216.0971461644035
# -4 th Day Short EMA: 3133.8719951104276 Long EMA: 2957.531951520281 Diff 176.3400435901467
# @STOCH, stoch comparison: 10
# 2018-10-10 00:00:00 2019-04-10 00:00:00
# 2018-04-10 00:00:00 2018-10-09 00:00:00
# 2017-04-10 00:00:00 2018-04-09 00:00:00
# Current Close:  3880.0
# Check between 2401.0    3880.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-10 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 1.5647065088413896
# Stochastic Value 10.701725067044574
# CF Value 0.0
# ##################################### Results =  32.26643157588596 %
# ------------------------------------------------ 472
# 2019-04-13, Close: 3734.00
# macd 286.32812119343043   Signal 208.56517718391515
# rsi 74.08927986012687
# short EMA 3517.243294876363
# long EMA 3230.9151736829326
# Bollinger Top 4086.7206712599805   Bollinger Bottom 2263.87932874002
# Stochastic K 56.636888637468935   Stochastic D: 74.17366809018723
# today Short EMA: 3517.243294876363 Long EMA: 3230.9151736829326 Diff:  286.32812119343043
# -1 th Day Short EMA: 3477.8329848538833 Long EMA: 3190.668387577567 Diff 287.1645972763163
# @STOCH, stoch comparison: 10
# 2018-10-13 00:00:00 2019-04-13 00:00:00
# 2018-04-15 00:00:00 2018-10-10 00:00:00
# 2017-04-15 00:00:00 2018-04-11 00:00:00
# Current Close:  3734.0
# Check between 2401.0    3880.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-13 /////////////////////
# RSI 1.9702400466243795
# MACD 10
# EMA DIFF 0
# Bollinger Bands 3.870009561801652
# Stochastic Value 14.051873051790153
# CF Value 0.7897227856659903
# ##################################### Results =  30.681845445882175 %
# ------------------------------------------------ 473
# 2019-04-14, Close: 3827.00
# macd 289.82856732571736   Signal 224.8178552122756
# rsi 76.15903879486117
# short EMA 3564.898172587692
# long EMA 3275.0696052619746
# Bollinger Top 4158.307037080243   Bollinger Bottom 2304.1929629197566
# Stochastic K 49.71514805449059   Stochastic D: 62.14665374088252
# today Short EMA: 3564.898172587692 Long EMA: 3275.0696052619746 Diff:  289.82856732571736
# -1 th Day Short EMA: 3517.243294876363 Long EMA: 3230.9151736829326 Diff 286.32812119343043
# -2 th Day Short EMA: 3477.8329848538833 Long EMA: 3190.668387577567 Diff 287.1645972763163
# @STOCH, stoch comparison: 10
# 2018-10-15 00:00:00 2019-04-14 00:00:00
# 2018-04-15 00:00:00 2018-10-13 00:00:00
# 2017-04-15 00:00:00 2018-04-11 00:00:00
# Current Close:  3827.0
# Check between 2401.0    3880.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-14 /////////////////////
# RSI 1.2803204017129417
# MACD 10
# EMA DIFF 2.5
# Bollinger Bands 3.5737503069249286
# Stochastic Value 15.040693135072772
# CF Value 0.2866801893171065
# ##################################### Results =  32.681444033027745 %
# ------------------------------------------------ 474
# 2019-04-15, Close: 3866.00
# macd 292.37930355670323   Signal 238.33014488116115
# rsi 76.98915555221805
# short EMA 3611.2215306511243
# long EMA 3318.842227094421
# Bollinger Top 4223.538831029178   Bollinger Bottom 2353.8611689708214
# Stochastic K 43.607580824972125   Stochastic D: 49.98653917231055
# today Short EMA: 3611.2215306511243 Long EMA: 3318.842227094421 Diff:  292.37930355670323
# -1 th Day Short EMA: 3564.898172587692 Long EMA: 3275.0696052619746 Diff 289.82856732571736
# -2 th Day Short EMA: 3517.243294876363 Long EMA: 3230.9151736829326 Diff 286.32812119343043
# -3 th Day Short EMA: 3477.8329848538833 Long EMA: 3190.668387577567 Diff 287.1645972763163
# @STOCH, stoch comparison: 10
# 2018-10-15 00:00:00 2019-04-15 00:00:00
# 2018-04-15 00:00:00 2018-10-13 00:00:00
# 2017-04-15 00:00:00 2018-04-11 00:00:00
# Current Close:  3866.0
# Check between 2401.0    3880.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-15 /////////////////////
# RSI 1.0036148159273175
# MACD 10
# EMA DIFF 5.0
# Bollinger Bands 3.824603976233618
# Stochastic Value 15.913202739289698
# CF Value 0.0757268424611226
# ##################################### Results =  35.817148373911756 %
# ------------------------------------------------ 475
# 2019-04-16, Close: 3810.00
# macd 286.5785492811883   Signal 247.9798257611666
# rsi 73.05567092835133
# short EMA 3641.8028336278744
# long EMA 3355.224284346686
# Bollinger Top 4261.905041452743   Bollinger Bottom 2429.094958547257
# Stochastic K 53.641025641025635   Stochastic D: 48.98791817349612
# today Short EMA: 3641.8028336278744 Long EMA: 3355.224284346686 Diff:  286.5785492811883
# -1 th Day Short EMA: 3611.2215306511243 Long EMA: 3318.842227094421 Diff 292.37930355670323
# @STOCH, stoch comparison: 0
# 2018-10-16 00:00:00 2019-04-16 00:00:00
# 2018-04-16 00:00:00 2018-10-15 00:00:00
# 2017-04-16 00:00:00 2018-04-15 00:00:00
# Current Close:  3810.0
# Check between 2401.0    3880.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-16 /////////////////////
# RSI 2.3147763572162248
# MACD 10
# EMA DIFF 0
# Bollinger Bands 4.9312806129520474
# Stochastic Value 4.479853479853481
# CF Value 0.3786342123056121
# ##################################### Results =  22.104544662327367 %
# ------------------------------------------------ 476
# 2019-04-17, Close: 3805.00
# macd 278.3690859681078   Signal 254.05767780255488
# rsi 72.69852953559621
# short EMA 3666.910089992817
# long EMA 3388.5410040247093
# Bollinger Top 4283.2902841115065   Bollinger Bottom 2522.0097158884937
# Stochastic K 54.2676887831527   Stochastic D: 50.50543174971682
# today Short EMA: 3666.910089992817 Long EMA: 3388.5410040247093 Diff:  278.3690859681078
# -1 th Day Short EMA: 3641.8028336278744 Long EMA: 3355.224284346686 Diff 286.5785492811883
# @STOCH, stoch comparison: 0
# 2018-10-17 00:00:00 2019-04-17 00:00:00
# 2018-04-17 00:00:00 2018-10-16 00:00:00
# 2017-04-17 00:00:00 2018-04-16 00:00:00
# Current Close:  3805.0
# Check between 2401.0    3880.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-17 /////////////////////
# RSI 2.4338234881345997
# MACD 10
# EMA DIFF 0
# Bollinger Bands 5.431165173122439
# Stochastic Value 4.390330173835329
# CF Value 0.40567951318458384
# ##################################### Results =  22.66099834827695 %
# ------------------------------------------------ 477
# 2019-04-20, Close: 3995.00
# macd 283.9215681476812   Signal 260.03045587158016
# rsi 77.24986207716151
# short EMA 3717.385460763153
# long EMA 3433.4638926154717
# Bollinger Top 4321.128403558263   Bollinger Bottom 2614.271596441736
# Stochastic K 66.47281698828091   Stochastic D: 58.12717713748642
# today Short EMA: 3717.385460763153 Long EMA: 3433.4638926154717 Diff:  283.9215681476812
# -1 th Day Short EMA: 3666.910089992817 Long EMA: 3388.5410040247093 Diff 278.3690859681078
# -2 th Day Short EMA: 3641.8028336278744 Long EMA: 3355.224284346686 Diff 286.5785492811883
# @STOCH, stoch comparison: 0
# 2018-10-20 00:00:00 2019-04-20 00:00:00
# 2018-04-21 00:00:00 2018-10-17 00:00:00
# 2017-04-22 00:00:00 2018-04-18 00:00:00
# Current Close:  3995.0
# Check between 2401.0    3995.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-20 /////////////////////
# RSI 0.9167126409461659
# MACD 10
# EMA DIFF 2.5
# Bollinger Bands 3.821391486368526
# Stochastic Value 2.6467404302455844
# CF Value 8.881784197001252e-16
# ##################################### Results =  19.884844557560278 %
# ------------------------------------------------ 478
# 2019-04-22, Close: 4173.00
# macd 299.23566024680395   Signal 267.8714967466249
# rsi 80.52533239303487
# short EMA 3787.4800052611295
# long EMA 3488.2443450143255
# Bollinger Top 4372.026594038965   Bollinger Bottom 2709.9734059610346
# Stochastic K 83.13477023111649   Stochastic D: 67.95842533418336
# today Short EMA: 3787.4800052611295 Long EMA: 3488.2443450143255 Diff:  299.23566024680395
# -1 th Day Short EMA: 3717.385460763153 Long EMA: 3433.4638926154717 Diff 283.9215681476812
# -2 th Day Short EMA: 3666.910089992817 Long EMA: 3388.5410040247093 Diff 278.3690859681078
# -3 th Day Short EMA: 3641.8028336278744 Long EMA: 3355.224284346686 Diff 286.5785492811883
# @STOCH, stoch comparison: 0
# 2018-10-22 00:00:00 2019-04-22 00:00:00
# 2018-04-22 00:00:00 2018-10-21 00:00:00
# 2017-04-22 00:00:00 2018-04-21 00:00:00
# Current Close:  4173.0
# Check between 2401.0    4173.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-22 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 5.0
# Bollinger Bands 2.3949485547947873
# Stochastic Value 0.26646139555478676
# CF Value 8.881784197001252e-16
# ##################################### Results =  17.661409950349572 %
# ------------------------------------------------ 479
# 2019-04-23, Close: 4233.00
# macd 312.6101123444432   Signal 276.81921986618863
# rsi 81.49260917151602
# short EMA 3856.021542913263
# long EMA 3543.41143056882
# Bollinger Top 4424.830230708635   Bollinger Bottom 2798.969769291365
# Stochastic K 92.94491378111529   Stochastic D: 80.85083366683756
# today Short EMA: 3856.021542913263 Long EMA: 3543.41143056882 Diff:  312.6101123444432
# -1 th Day Short EMA: 3787.4800052611295 Long EMA: 3488.2443450143255 Diff 299.23566024680395
# -2 th Day Short EMA: 3717.385460763153 Long EMA: 3433.4638926154717 Diff 283.9215681476812
# -3 th Day Short EMA: 3666.910089992817 Long EMA: 3388.5410040247093 Diff 278.3690859681078
# -4 th Day Short EMA: 3641.8028336278744 Long EMA: 3355.224284346686 Diff 286.5785492811883
# @STOCH, stoch comparison: 0
# 2018-10-23 00:00:00 2019-04-23 00:00:00
# 2018-04-23 00:00:00 2018-10-22 00:00:00
# 2017-04-23 00:00:00 2018-04-22 00:00:00
# Current Close:  4233.0
# Check between 2401.0    4233.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-23 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 7.5
# Bollinger Bands 2.3597379389054787
# Stochastic Value 0
# CF Value 0.0
# ##################################### Results =  19.85973793890548 %
# ------------------------------------------------ 480
# 2019-04-24, Close: 4277.00
# macd 323.03613478738635   Signal 286.06260285042816
# rsi 82.1911668680203
# short EMA 3920.7874593881456
# long EMA 3597.7513246007593
# Bollinger Top 4464.295893647107   Bollinger Bottom 2903.304106352893
# Stochastic K 88.24171743408333   Stochastic D: 88.10713381543837
# today Short EMA: 3920.7874593881456 Long EMA: 3597.7513246007593 Diff:  323.03613478738635
# -1 th Day Short EMA: 3856.021542913263 Long EMA: 3543.41143056882 Diff 312.6101123444432
# -2 th Day Short EMA: 3787.4800052611295 Long EMA: 3488.2443450143255 Diff 299.23566024680395
# -3 th Day Short EMA: 3717.385460763153 Long EMA: 3433.4638926154717 Diff 283.9215681476812
# -4 th Day Short EMA: 3666.910089992817 Long EMA: 3388.5410040247093 Diff 278.3690859681078
# @STOCH, stoch comparison: 0
# 2018-10-24 00:00:00 2019-04-24 00:00:00
# 2018-04-24 00:00:00 2018-10-23 00:00:00
# 2017-04-24 00:00:00 2018-04-23 00:00:00
# Current Close:  4277.0
# Check between 2401.0    4277.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-24 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 2.399703767458778
# Stochastic Value 0
# CF Value 0.0
# ##################################### Results =  22.399703767458778 %
# ------------------------------------------------ 481
# 2019-04-27, Close: 4337.00
# macd 332.309672202372   Signal 295.3120167208169
# rsi 83.12645755769249
# short EMA 3984.8201579438155
# long EMA 3652.5104857414435
# Bollinger Top 4495.002496441523   Bollinger Bottom 3017.8975035584763
# Stochastic K 81.2500938615774   Stochastic D: 87.47890835892535
# today Short EMA: 3984.8201579438155 Long EMA: 3652.5104857414435 Diff:  332.309672202372
# -1 th Day Short EMA: 3920.7874593881456 Long EMA: 3597.7513246007593 Diff 323.03613478738635
# -2 th Day Short EMA: 3856.021542913263 Long EMA: 3543.41143056882 Diff 312.6101123444432
# -3 th Day Short EMA: 3787.4800052611295 Long EMA: 3488.2443450143255 Diff 299.23566024680395
# -4 th Day Short EMA: 3717.385460763153 Long EMA: 3433.4638926154717 Diff 283.9215681476812
# @STOCH, stoch comparison: 10
# 2018-10-27 00:00:00 2019-04-27 00:00:00
# 2018-04-28 00:00:00 2018-10-24 00:00:00
# 2017-04-29 00:00:00 2018-04-25 00:00:00
# Current Close:  4337.0
# Check between 2401.0    4337.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-27 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 2.1393536302809544
# Stochastic Value 10.535700876917515
# CF Value 0.0
# ##################################### Results =  32.67505450719847 %
# ------------------------------------------------ 482
# 2019-04-28, Close: 4209.00
# macd 325.57743317192035   Signal 301.3651000110376
# rsi 74.17650164035085
# short EMA 4019.3093644139976
# long EMA 3693.7319312420773
# Bollinger Top 4485.198401618971   Bollinger Bottom 3152.6015983810294
# Stochastic K 67.42491943962041   Stochastic D: 78.97224357842704
# today Short EMA: 4019.3093644139976 Long EMA: 3693.7319312420773 Diff:  325.57743317192035
# -1 th Day Short EMA: 3984.8201579438155 Long EMA: 3652.5104857414435 Diff 332.309672202372
# @STOCH, stoch comparison: 10
# 2018-10-28 00:00:00 2019-04-28 00:00:00
# 2018-04-28 00:00:00 2018-10-27 00:00:00
# 2017-04-29 00:00:00 2018-04-25 00:00:00
# Current Close:  4209.0
# Check between 2401.0    4337.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-28 /////////////////////
# RSI 1.94116611988305
# MACD 10
# EMA DIFF 0
# Bollinger Bands 4.1452658590785205
# Stochastic Value 12.510725794339942
# CF Value 0.5289256198347108
# ##################################### Results =  29.12608339313622 %
# ------------------------------------------------ 483
# 2019-04-29, Close: 4389.00
# macd 330.9515771432543   Signal 307.28239543748094
# rsi 77.79680035177864
# short EMA 4076.184846811844
# long EMA 3745.23326966859
# Bollinger Top 4508.6264259583395   Bollinger Bottom 3257.2735740416597
# Stochastic K 66.7772385936699   Stochastic D: 71.81741729828923
# today Short EMA: 4076.184846811844 Long EMA: 3745.23326966859 Diff:  330.9515771432543
# -1 th Day Short EMA: 4019.3093644139976 Long EMA: 3693.7319312420773 Diff 325.57743317192035
# -2 th Day Short EMA: 3984.8201579438155 Long EMA: 3652.5104857414435 Diff 332.309672202372
# @STOCH, stoch comparison: 10
# 2018-10-29 00:00:00 2019-04-29 00:00:00
# 2018-04-29 00:00:00 2018-10-28 00:00:00
# 2017-04-29 00:00:00 2018-04-28 00:00:00
# Current Close:  4389.0
# Check between 2401.0    4389.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-29 /////////////////////
# RSI 0.7343998827404548
# MACD 10
# EMA DIFF 2.5
# Bollinger Bands 1.9119535433208839
# Stochastic Value 12.603251629475729
# CF Value 0.0
# ##################################### Results =  27.749605055537067 %
# ------------------------------------------------ 484
# 2019-04-30, Close: 4516.00
# macd 341.521614988108   Signal 314.1302393476064
# rsi 79.93427104955168
# short EMA 4143.848716533099
# long EMA 3802.327101544991
# Bollinger Top 4554.814323176525   Bollinger Bottom 3339.985676823475
# Stochastic K 68.50292031935163   Stochastic D: 67.56835945088065
# today Short EMA: 4143.848716533099 Long EMA: 3802.327101544991 Diff:  341.521614988108
# -1 th Day Short EMA: 4076.184846811844 Long EMA: 3745.23326966859 Diff 330.9515771432543
# -2 th Day Short EMA: 4019.3093644139976 Long EMA: 3693.7319312420773 Diff 325.57743317192035
# -3 th Day Short EMA: 3984.8201579438155 Long EMA: 3652.5104857414435 Diff 332.309672202372
# @STOCH, stoch comparison: 0
# 2018-10-31 00:00:00 2019-04-30 00:00:00
# 2018-04-30 00:00:00 2018-10-29 00:00:00
# 2017-04-30 00:00:00 2018-04-29 00:00:00
# Current Close:  4516.0
# Check between 2401.0    4516.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-04-30 /////////////////////
# RSI 0.02190965014943913
# MACD 10
# EMA DIFF 5.0
# Bollinger Bands 0.6390090206227335
# Stochastic Value 2.356725668664053
# CF Value 0.0
# ##################################### Results =  18.017644339436224 %
# ------------------------------------------------ 485
# 2019-05-01, Close: 4660.00
# macd 357.3981789407644   Signal 322.783827266238
# rsi 82.04491738455476
# short EMA 4223.256606297237
# long EMA 3865.858427356473
# Bollinger Top 4628.254505312596   Bollinger Bottom 3399.1454946874037
# Stochastic K 83.64039773579248   Stochastic D: 72.97351888293802
# today Short EMA: 4223.256606297237 Long EMA: 3865.858427356473 Diff:  357.3981789407644
# -1 th Day Short EMA: 4143.848716533099 Long EMA: 3802.327101544991 Diff 341.521614988108
# -2 th Day Short EMA: 4076.184846811844 Long EMA: 3745.23326966859 Diff 330.9515771432543
# -3 th Day Short EMA: 4019.3093644139976 Long EMA: 3693.7319312420773 Diff 325.57743317192035
# -4 th Day Short EMA: 3984.8201579438155 Long EMA: 3652.5104857414435 Diff 332.309672202372
# @STOCH, stoch comparison: 0
# 2018-11-03 00:00:00 2019-05-01 00:00:00
# 2018-05-01 00:00:00 2018-10-31 00:00:00
# 2017-05-01 00:00:00 2018-04-30 00:00:00
# Current Close:  4660.0
# Check between 2401.0    4660.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-01 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 7.5
# Bollinger Bands 0
# Stochastic Value 0.1942288948867894
# CF Value 0.0
# ##################################### Results =  17.69422889488679 %
# ------------------------------------------------ 486
# 2019-05-04, Close: 4873.00
# macd 382.7556215938057   Signal 334.77818613175157
# rsi 84.62166375854781
# short EMA 4323.217128405355
# long EMA 3940.461506811549
# Bollinger Top 4753.152463785231   Bollinger Bottom 3413.7475362147693
# Stochastic K 88.08052811638878   Stochastic D: 80.07461539051097
# today Short EMA: 4323.217128405355 Long EMA: 3940.461506811549 Diff:  382.7556215938057
# -1 th Day Short EMA: 4223.256606297237 Long EMA: 3865.858427356473 Diff 357.3981789407644
# -2 th Day Short EMA: 4143.848716533099 Long EMA: 3802.327101544991 Diff 341.521614988108
# -3 th Day Short EMA: 4076.184846811844 Long EMA: 3745.23326966859 Diff 330.9515771432543
# -4 th Day Short EMA: 4019.3093644139976 Long EMA: 3693.7319312420773 Diff 325.57743317192035
# @STOCH, stoch comparison: 0
# 2018-11-04 00:00:00 2019-05-04 00:00:00
# 2018-05-05 00:00:00 2018-11-03 00:00:00
# 2017-05-06 00:00:00 2018-05-01 00:00:00
# Current Close:  4873.0
# Check between 2401.0    4873.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-04 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 0.0
# ##################################### Results =  20.0 %
# ------------------------------------------------ 487
# 2019-05-05, Close: 5042.00
# macd 411.7421578992503   Signal 350.17098048525133
# rsi 86.3014383885961
# short EMA 4433.7991086506845
# long EMA 4022.056950751434
# Bollinger Top 4909.202331739918   Bollinger Bottom 3399.5976682600817
# Stochastic K 91.96944777204709   Stochastic D: 87.89679120807612
# today Short EMA: 4433.7991086506845 Long EMA: 4022.056950751434 Diff:  411.7421578992503
# -1 th Day Short EMA: 4323.217128405355 Long EMA: 3940.461506811549 Diff 382.7556215938057
# -2 th Day Short EMA: 4223.256606297237 Long EMA: 3865.858427356473 Diff 357.3981789407644
# -3 th Day Short EMA: 4143.848716533099 Long EMA: 3802.327101544991 Diff 341.521614988108
# -4 th Day Short EMA: 4076.184846811844 Long EMA: 3745.23326966859 Diff 330.9515771432543
# @STOCH, stoch comparison: 0
# 2018-11-05 00:00:00 2019-05-05 00:00:00
# 2018-05-05 00:00:00 2018-11-04 00:00:00
# 2017-05-06 00:00:00 2018-05-01 00:00:00
# Current Close:  5042.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-05 /////////////////////
# RSI 0
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 0.0
# ##################################### Results =  20.0 %
# ------------------------------------------------ 488
# 2019-05-06, Close: 4916.00
# macd 419.70890676648696   Signal 364.0785657414985
# rsi 79.34289658589813
# short EMA 4507.983861165963
# long EMA 4088.2749543994764
# Bollinger Top 5015.073449294814   Bollinger Bottom 3405.726550705185
# Stochastic K 86.6632635371238   Stochastic D: 88.90441314185323
# today Short EMA: 4507.983861165963 Long EMA: 4088.2749543994764 Diff:  419.70890676648696
# -1 th Day Short EMA: 4433.7991086506845 Long EMA: 4022.056950751434 Diff 411.7421578992503
# -2 th Day Short EMA: 4323.217128405355 Long EMA: 3940.461506811549 Diff 382.7556215938057
# -3 th Day Short EMA: 4223.256606297237 Long EMA: 3865.858427356473 Diff 357.3981789407644
# -4 th Day Short EMA: 4143.848716533099 Long EMA: 3802.327101544991 Diff 341.521614988108
# @STOCH, stoch comparison: 10
# 2018-11-06 00:00:00 2019-05-06 00:00:00
# 2018-05-06 00:00:00 2018-11-05 00:00:00
# 2017-05-06 00:00:00 2018-05-05 00:00:00
# Current Close:  4916.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-06 /////////////////////
# RSI 0.2190344713672907
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 1.2312255285872595
# Stochastic Value 10
# CF Value 0.3816736084816359
# ##################################### Results =  31.831933608436188 %
# ------------------------------------------------ 489
# 2019-05-07, Close: 4680.00
# macd 402.3414432662721   Signal 371.73114124645326
# rsi 68.24375782974965
# short EMA 4534.447882525046
# long EMA 4132.106439258774
# Bollinger Top 5064.049520117977   Bollinger Bottom 3438.6504798820233
# Stochastic K 65.03204392265144   Stochastic D: 81.2215850772741
# today Short EMA: 4534.447882525046 Long EMA: 4132.106439258774 Diff:  402.3414432662721
# -1 th Day Short EMA: 4507.983861165963 Long EMA: 4088.2749543994764 Diff 419.70890676648696
# @STOCH, stoch comparison: 10
# 2018-11-10 00:00:00 2019-05-07 00:00:00
# 2018-05-07 00:00:00 2018-11-06 00:00:00
# 2017-05-07 00:00:00 2018-05-06 00:00:00
# Current Close:  4680.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-07 /////////////////////
# RSI 3.9187473900834497
# MACD 10
# EMA DIFF 0
# Bollinger Bands 4.725602890256734
# Stochastic Value 12.852565153906937
# CF Value 1.0965543354789853
# ##################################### Results =  32.593469769726106 %
# ------------------------------------------------ 490
# 2019-05-08, Close: 4456.00
# macd 366.28042265195745   Signal 370.64099752755413
# rsi 59.70641152638911
# short EMA 4522.378977521193
# long EMA 4156.098554869235
# Bollinger Top 5074.325935809302   Bollinger Bottom 3493.4740641906974
# Stochastic K 34.83598233485119   Stochastic D: 62.177096598208806
# today Short EMA: 4522.378977521193 Long EMA: 4156.098554869235 Diff:  366.28042265195745
# -1 th Day Short EMA: 4534.447882525046 Long EMA: 4132.106439258774 Diff 402.3414432662721
# @STOCH, stoch comparison: 10
# 2018-11-10 00:00:00 2019-05-08 00:00:00
# 2018-05-08 00:00:00 2018-11-06 00:00:00
# 2017-05-08 00:00:00 2018-05-07 00:00:00
# Current Close:  4456.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-08 /////////////////////
# RSI 6.76452949120363
# MACD 0
# EMA DIFF 0
# Bollinger Bands 7.8226929026083845
# Stochastic Value 17.1662882378784
# CF Value 1.7750851950018935
# ##################################### Results =  33.52859582669231 %
# ------------------------------------------------ 491
# 2019-05-11, Close: 4340.00
# macd 324.5997891489824   Signal 361.43275585183983
# rsi 55.81249986701911
# short EMA 4494.320673287163
# long EMA 4169.720884138181
# Bollinger Top 5075.443791855751   Bollinger Bottom 3538.356208144248
# Stochastic K 15.12220255554191   Stochastic D: 38.33007627101486
# today Short EMA: 4494.320673287163 Long EMA: 4169.720884138181 Diff:  324.5997891489824
# -1 th Day Short EMA: 4522.378977521193 Long EMA: 4156.098554869235 Diff 366.28042265195745
# @STOCH, stoch comparison: 10
# 2018-11-11 00:00:00 2019-05-11 00:00:00
# 2018-05-12 00:00:00 2018-11-10 00:00:00
# 2017-05-13 00:00:00 2018-05-09 00:00:00
# Current Close:  4340.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-11 /////////////////////
# RSI 8.062500044326963
# MACD 0
# EMA DIFF 0
# Bollinger Bands 9.569315368222858
# Stochastic Value 19.98254249206544
# CF Value 2.126467247254828
# ##################################### Results =  39.74082515187009 %
# ------------------------------------------------ 492
# 2019-05-12, Close: 4159.00
# macd 273.8061328244403   Signal 343.9074312463599
# rsi 50.300116833628124
# short EMA 4442.73287739683
# long EMA 4168.92674457239
# Bollinger Top 5054.5006797684   Bollinger Bottom 3601.7993202315993
# Stochastic K 5.499287450430284   Stochastic D: 18.4858241136078
# today Short EMA: 4442.73287739683 Long EMA: 4168.92674457239 Diff:  273.8061328244403
# -1 th Day Short EMA: 4494.320673287163 Long EMA: 4169.720884138181 Diff 324.5997891489824
# @STOCH, stoch comparison: 10
# 2018-11-12 00:00:00 2019-05-12 00:00:00
# 2018-05-12 00:00:00 2018-11-11 00:00:00
# 2017-05-13 00:00:00 2018-05-09 00:00:00
# Current Close:  4159.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-12 /////////////////////
# RSI 9.899961055457293
# MACD 0
# EMA DIFF 0
# Bollinger Bands 12.3287649438689
# Stochastic Value 20
# CF Value 2.6747444149943203
# ##################################### Results =  44.903470414320516 %
# ------------------------------------------------ 493
# 2019-05-13, Close: 4058.00
# macd 222.8332552730244   Signal 319.6925960516929
# rsi 47.481966898434365
# short EMA 4383.543203951163
# long EMA 4160.709948678139
# Bollinger Top 5040.711868658442   Bollinger Bottom 3638.688131341558
# Stochastic K 9.453538608628811   Stochastic D: 10.025009538200335
# today Short EMA: 4383.543203951163 Long EMA: 4160.709948678139 Diff:  222.8332552730244
# -1 th Day Short EMA: 4442.73287739683 Long EMA: 4168.92674457239 Diff 273.8061328244403
# @STOCH, stoch comparison: 10
# 2018-11-13 00:00:00 2019-05-13 00:00:00
# 2018-05-13 00:00:00 2018-11-12 00:00:00
# 2017-05-13 00:00:00 2018-05-12 00:00:00
# Current Close:  4058.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-13 /////////////////////
# RSI 10.839344367188545
# MACD 0
# EMA DIFF 0
# Bollinger Bands 14.018476898816303
# Stochastic Value 20
# CF Value 2.980689132904203
# ##################################### Results =  47.83851039890905 %
# ------------------------------------------------ 494
# 2019-05-14, Close: 4244.00
# macd 195.19543661851912   Signal 294.7931641650581
# rsi 52.733921107139636
# short EMA 4362.075018727907
# long EMA 4166.879582109388
# Bollinger Top 5027.137328800705   Bollinger Bottom 3690.0626711992954
# Stochastic K 21.872664954088933   Stochastic D: 12.275163671049341
# today Short EMA: 4362.075018727907 Long EMA: 4166.879582109388 Diff:  195.19543661851912
# -1 th Day Short EMA: 4383.543203951163 Long EMA: 4160.709948678139 Diff 222.8332552730244
# @STOCH, stoch comparison: 0
# 2018-11-14 00:00:00 2019-05-14 00:00:00
# 2018-05-14 00:00:00 2018-11-13 00:00:00
# 2017-05-14 00:00:00 2018-05-13 00:00:00
# Current Close:  4244.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-14 /////////////////////
# RSI 9.088692964286789
# MACD 0
# EMA DIFF 0
# Bollinger Bands 11.714189994530035
# Stochastic Value 9.018190720844439
# CF Value 2.41726618705036
# ##################################### Results =  32.23833986671162 %
# ------------------------------------------------ 495
# 2019-05-15, Close: 4291.00
# macd 175.066713323753   Signal 270.8478739967971
# rsi 53.986113306823725
# short EMA 4351.140400462075
# long EMA 4176.073687138322
# Bollinger Top 5003.415744866785   Bollinger Bottom 3761.8842551332145
# Stochastic K 40.153438626047596   Stochastic D: 23.826547396255112
# today Short EMA: 4351.140400462075 Long EMA: 4176.073687138322 Diff:  175.066713323753
# -1 th Day Short EMA: 4362.075018727907 Long EMA: 4166.879582109388 Diff 195.19543661851912
# @STOCH, stoch comparison: 0
# 2018-11-17 00:00:00 2019-05-15 00:00:00
# 2018-05-15 00:00:00 2018-11-14 00:00:00
# 2017-05-15 00:00:00 2018-05-14 00:00:00
# Current Close:  4291.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-15 /////////////////////
# RSI 8.671295564392093
# MACD 0
# EMA DIFF 0
# Bollinger Bands 11.476402342717341
# Stochastic Value 6.406651624850344
# CF Value 2.2748958727754642
# ##################################### Results =  28.82924540473524 %
# ------------------------------------------------ 496
# 2019-05-18, Close: 4494.00
# macd 173.49501600365056   Signal 251.3773023981678
# rsi 59.03418879954397
# short EMA 4373.1188003909865
# long EMA 4199.623784387336
# Bollinger Top 4979.547117514163   Bollinger Bottom 3854.652882485838
# Stochastic K 68.39598592255892   Stochastic D: 43.47402983423182
# today Short EMA: 4373.1188003909865 Long EMA: 4199.623784387336 Diff:  173.49501600365056
# -1 th Day Short EMA: 4351.140400462075 Long EMA: 4176.073687138322 Diff 175.066713323753
# @STOCH, stoch comparison: 0
# 2018-11-18 00:00:00 2019-05-18 00:00:00
# 2018-05-19 00:00:00 2018-11-17 00:00:00
# 2017-05-20 00:00:00 2018-05-16 00:00:00
# Current Close:  4494.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-18 /////////////////////
# RSI 6.988603733485345
# MACD 0
# EMA DIFF 0
# Bollinger Bands 8.632760350166373
# Stochastic Value 2.372002011063012
# CF Value 1.6599772813328286
# ##################################### Results =  19.65334337604756 %
# ------------------------------------------------ 497
# 2019-05-19, Close: 4320.00
# macd 156.4061361545264   Signal 232.38306914943954
# rsi 53.60562234729704
# short EMA 4364.946677253912
# long EMA 4208.540541099385
# Bollinger Top 4963.955795294389   Bollinger Bottom 3902.744204705612
# Stochastic K 74.30154614842733   Stochastic D: 60.950323565677955
# today Short EMA: 4364.946677253912 Long EMA: 4208.540541099385 Diff:  156.4061361545264
# -1 th Day Short EMA: 4373.1188003909865 Long EMA: 4199.623784387336 Diff 173.49501600365056
# @STOCH, stoch comparison: 0
# 2018-11-19 00:00:00 2019-05-19 00:00:00
# 2018-05-19 00:00:00 2018-11-18 00:00:00
# 2017-05-20 00:00:00 2018-05-16 00:00:00
# Current Close:  4320.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-19 /////////////////////
# RSI 8.79812588423432
# MACD 0
# EMA DIFF 0
# Bollinger Bands 12.136237504475652
# Stochastic Value 1.5283505502246673
# CF Value 2.187050359712231
# ##################################### Results =  24.649764298646872 %
# ------------------------------------------------ 498
# 2019-05-20, Close: 4116.00
# macd 124.96150224248322   Signal 210.8987557680483
# rsi 48.02923618117155
# short EMA 4326.647188445618
# long EMA 4201.6856862031345
# Bollinger Top 4967.245563558747   Bollinger Bottom 3893.754436441253
# Stochastic K 55.84982690951944   Stochastic D: 66.1824529935019
# today Short EMA: 4326.647188445618 Long EMA: 4201.6856862031345 Diff:  124.96150224248322
# -1 th Day Short EMA: 4364.946677253912 Long EMA: 4208.540541099385 Diff 156.4061361545264
# @STOCH, stoch comparison: 10
# 2018-11-20 00:00:00 2019-05-20 00:00:00
# 2018-05-20 00:00:00 2018-11-19 00:00:00
# 2017-05-20 00:00:00 2018-05-19 00:00:00
# Current Close:  4116.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-20 /////////////////////
# RSI 10.656921272942817
# MACD 0
# EMA DIFF 0
# Bollinger Bands 15.859387042061275
# Stochastic Value 14.164310441497223
# CF Value 2.8049981067777363
# ##################################### Results =  43.485616863279056 %
# ------------------------------------------------ 499
# 2019-05-21, Close: 4283.00
# macd 112.22326767045433   Signal 191.1636581485295
# rsi 52.39505357254163
# short EMA 4319.932236377061
# long EMA 4207.708968706606
# Bollinger Top 4966.498641047939   Bollinger Bottom 3899.5013589520618
# Stochastic K 38.05901160299973   Stochastic D: 56.0701282203155
# today Short EMA: 4319.932236377061 Long EMA: 4207.708968706606 Diff:  112.22326767045433
# -1 th Day Short EMA: 4326.647188445618 Long EMA: 4201.6856862031345 Diff 124.96150224248322
# @STOCH, stoch comparison: 10
# 2018-11-21 00:00:00 2019-05-21 00:00:00
# 2018-05-21 00:00:00 2018-11-20 00:00:00
# 2017-05-21 00:00:00 2018-05-20 00:00:00
# Current Close:  4283.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# Check between 2356.0    3196.0
# //////////////// 2019-05-21 /////////////////////
# RSI 9.201648809152791
# MACD 0
# EMA DIFF 0
# Bollinger Bands 12.811628530212538
# Stochastic Value 16.705855485285753
# CF Value 2.299129117758425
# ##################################### Results =  41.01826194240951 %
# ------------------------------------------------ 500
# 2019-05-22, Close: 4391.00
# ...
# Check between 4392.0    8356.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-11-27 /////////////////////
# RSI 5.663442102466973
# MACD 10
# EMA DIFF 7.5
# Bollinger Bands 3.7439142089478317
# Stochastic Value 0
# CF Value 0.07870837537840547
# ##################################### Results =  26.98606468679321 %
# ------------------------------------------------ 622
# 2019-11-30, Close: 8378.00
# macd 264.7363967599358   Signal 245.19211192659012
# rsi 64.0167736297461
# short EMA 8076.900493821231
# long EMA 7812.164097061295
# Bollinger Top 8595.756641051474   Bollinger Bottom 7325.243358948527
# Stochastic K 81.24338624338624   Stochastic D: 82.86377703050128
# today Short EMA: 8076.900493821231 Long EMA: 7812.164097061295 Diff:  264.7363967599358
# -1 th Day Short EMA: 8022.155129061455 Long EMA: 7766.897224826198 Diff 255.25790423525723
# -2 th Day Short EMA: 7968.546970708992 Long EMA: 7722.889002812294 Diff 245.6579678966982
# -3 th Day Short EMA: 7905.555510837899 Long EMA: 7675.520123037278 Diff 230.03538780062172
# -4 th Day Short EMA: 7835.838330990245 Long EMA: 7626.44173288026 Diff 209.39659810998455
# @STOCH, stoch comparison: 10
# 2019-06-01 00:00:00 2019-11-30 00:00:00
# 2018-12-01 00:00:00 2019-05-29 00:00:00
# 2017-12-02 00:00:00 2018-11-28 00:00:00
# Current Close:  8378.0
# Check between 4657.0    8378.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-11-30 /////////////////////
# RSI 5.327742123417968
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 3.4278530436304315
# Stochastic Value 10.536659108087681
# CF Value 8.881784197001252e-16
# ##################################### Results =  39.29225427513608 %
# ------------------------------------------------ 623
# 2019-12-01, Close: 8359.00
# macd 267.62995760679314   Signal 249.67968106263075
# rsi 63.43742709159544
# short EMA 8120.300417848734
# long EMA 7852.67046024194
# Bollinger Top 8580.316665681068   Bollinger Bottom 7452.98333431893
# Stochastic K 75.96265523094792   Stochastic D: 80.82731618303603
# today Short EMA: 8120.300417848734 Long EMA: 7852.67046024194 Diff:  267.62995760679314
# -1 th Day Short EMA: 8076.900493821231 Long EMA: 7812.164097061295 Diff 264.7363967599358
# -2 th Day Short EMA: 8022.155129061455 Long EMA: 7766.897224826198 Diff 255.25790423525723
# -3 th Day Short EMA: 7968.546970708992 Long EMA: 7722.889002812294 Diff 245.6579678966982
# -4 th Day Short EMA: 7905.555510837899 Long EMA: 7675.520123037278 Diff 230.03538780062172
# @STOCH, stoch comparison: 10
# 2019-06-01 00:00:00 2019-12-01 00:00:00
# 2018-12-01 00:00:00 2019-05-29 00:00:00
# 2017-12-02 00:00:00 2018-11-28 00:00:00
# Current Close:  8359.0
# Check between 4657.0    8378.0
# Check between 2401.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-01 /////////////////////
# RSI 5.5208576361348545
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 3.92637491545921
# Stochastic Value 11.291049252721727
# CF Value 0.040849234076861585
# ##################################### Results =  40.77913103839265 %
# ------------------------------------------------ 624
# 2019-12-02, Close: 8313.00
# macd 263.17756274200474   Signal 252.37925739850556
# rsi 61.97507941369765
# short EMA 8149.946507410467
# long EMA 7886.768944668463
# Bollinger Top 8592.706445889828   Bollinger Bottom 7514.493554110174
# Stochastic K 63.52005717859377   Stochastic D: 73.57536621764264
# today Short EMA: 8149.946507410467 Long EMA: 7886.768944668463 Diff:  263.17756274200474
# -1 th Day Short EMA: 8120.300417848734 Long EMA: 7852.67046024194 Diff 267.62995760679314
# @STOCH, stoch comparison: 10
# 2019-06-02 00:00:00 2019-12-02 00:00:00
# 2018-12-02 00:00:00 2019-06-01 00:00:00
# 2017-12-02 00:00:00 2018-12-01 00:00:00
# Current Close:  8313.0
# Check between 4685.0    8378.0
# Check between 2486.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-02 /////////////////////
# RSI 6.008306862100785
# MACD 10
# EMA DIFF 0
# Bollinger Bands 5.18833428949557
# Stochastic Value 13.068563260200891
# CF Value 0.14080693203357697
# ##################################### Results =  34.40601134383082 %
# ------------------------------------------------ 625
# 2019-12-03, Close: 8345.00
# macd 259.24275123549523   Signal 253.7519561659035
# rsi 62.620606046815304
# short EMA 8179.954737039627
# long EMA 7920.7119858041315
# Bollinger Top 8600.351706607478   Bollinger Bottom 7582.248293392522
# Stochastic K 51.444652908067546   Stochastic D: 63.64245510586974
# today Short EMA: 8179.954737039627 Long EMA: 7920.7119858041315 Diff:  259.24275123549523
# -1 th Day Short EMA: 8149.946507410467 Long EMA: 7886.768944668463 Diff 263.17756274200474
# @STOCH, stoch comparison: 10
# 2019-06-03 00:00:00 2019-12-03 00:00:00
# 2018-12-03 00:00:00 2019-06-02 00:00:00
# 2017-12-03 00:00:00 2018-12-02 00:00:00
# Current Close:  8345.0
# Check between 4696.0    8378.0
# Check between 2486.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-03 /////////////////////
# RSI 5.793131317728232
# MACD 10
# EMA DIFF 0
# Bollinger Bands 5.016223367744763
# Stochastic Value 14.793621013133208
# CF Value 0.0717001629549161
# ##################################### Results =  35.67467586156112 %
# ------------------------------------------------ 626
# 2019-12-04, Close: 8299.00
# macd 249.53607269067288   Signal 252.90877947085738
# rsi 61.017030394878994
# short EMA 8198.269392879683
# long EMA 7948.733320189011
# Bollinger Top 8609.823578574138   Bollinger Bottom 7627.976421425861
# Stochastic K 42.926829268292686   Stochastic D: 52.630513118318
# today Short EMA: 8198.269392879683 Long EMA: 7948.733320189011 Diff:  249.53607269067288
# -1 th Day Short EMA: 8179.954737039627 Long EMA: 7920.7119858041315 Diff 259.24275123549523
# @STOCH, stoch comparison: 10
# 2019-06-08 00:00:00 2019-12-04 00:00:00
# 2018-12-04 00:00:00 2019-06-03 00:00:00
# 2017-12-04 00:00:00 2018-12-03 00:00:00
# Current Close:  8299.0
# Check between 4696.0    8378.0
# Check between 2491.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-04 /////////////////////
# RSI 6.327656535040337
# MACD 0
# EMA DIFF 0
# Bollinger Bands 6.331404563555671
# Stochastic Value 16.010452961672474
# CF Value 0.17164584464964783
# ##################################### Results =  28.84115990491813 %
# ------------------------------------------------ 627
# 2019-12-07, Close: 8318.00
# macd 240.60307870039196   Signal 250.4476393167643
# rsi 61.45607493228878
# short EMA 8216.689486282809
# long EMA 7976.0864075824165
# Bollinger Top 8628.405488631206   Bollinger Bottom 7631.794511368795
# Stochastic K 43.333333333333336   Stochastic D: 45.901605169897856
# today Short EMA: 8216.689486282809 Long EMA: 7976.0864075824165 Diff:  240.60307870039196
# -1 th Day Short EMA: 8198.269392879683 Long EMA: 7948.733320189011 Diff 249.53607269067288
# @STOCH, stoch comparison: 10
# 2019-06-08 00:00:00 2019-12-07 00:00:00
# 2018-12-08 00:00:00 2019-06-03 00:00:00
# 2017-12-09 00:00:00 2018-12-05 00:00:00
# Current Close:  8318.0
# Check between 4696.0    8378.0
# Check between 2491.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-07 /////////////////////
# RSI 6.181308355903742
# MACD 0
# EMA DIFF 0
# Bollinger Bands 6.229220743360829
# Stochastic Value 15.952380952380953
# CF Value 0.13036393264530233
# ##################################### Results =  28.493273984290823 %
# ------------------------------------------------ 628
# 2019-12-08, Close: 8594.00
# macd 252.8794728253797   Signal 250.9340060184874
# rsi 67.22976400323923
# short EMA 8274.737257623914
# long EMA 8021.857784798534
# Bollinger Top 8691.32327077626   Bollinger Bottom 7635.576729223739
# Stochastic K 52.47746252972735   Stochastic D: 46.24587504378446
# today Short EMA: 8274.737257623914 Long EMA: 8021.857784798534 Diff:  252.8794728253797
# -1 th Day Short EMA: 8216.689486282809 Long EMA: 7976.0864075824165 Diff 240.60307870039196
# -2 th Day Short EMA: 8198.269392879683 Long EMA: 7948.733320189011 Diff 249.53607269067288
# @STOCH, stoch comparison: 0
# 2019-06-08 00:00:00 2019-12-08 00:00:00
# 2018-12-08 00:00:00 2019-06-03 00:00:00
# 2017-12-09 00:00:00 2018-12-05 00:00:00
# Current Close:  8594.0
# Check between 4696.0    8594.0
# Check between 2491.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-08 /////////////////////
# RSI 4.256745332253592
# MACD 10
# EMA DIFF 2.5
# Bollinger Bands 1.843686281617213
# Stochastic Value 4.646076781467522
# CF Value 8.881784197001252e-16
# ##################################### Results =  23.246508395338328 %
# ------------------------------------------------ 629
# 2019-12-09, Close: 8958.00
# macd 288.6529500136139   Signal 258.47779481751274
# rsi 72.97862582488094
# short EMA 8379.85460260485
# long EMA 8091.201652591236
# Bollinger Top 8828.429450715588   Bollinger Bottom 7566.970549284414
# Stochastic K 70.61141529782644   Stochastic D: 55.474070386962374
# today Short EMA: 8379.85460260485 Long EMA: 8091.201652591236 Diff:  288.6529500136139
# -1 th Day Short EMA: 8274.737257623914 Long EMA: 8021.857784798534 Diff 252.8794728253797
# -2 th Day Short EMA: 8216.689486282809 Long EMA: 7976.0864075824165 Diff 240.60307870039196
# -3 th Day Short EMA: 8198.269392879683 Long EMA: 7948.733320189011 Diff 249.53607269067288
# @STOCH, stoch comparison: 0
# 2019-06-09 00:00:00 2019-12-09 00:00:00
# 2018-12-09 00:00:00 2019-06-08 00:00:00
# 2017-12-09 00:00:00 2018-12-08 00:00:00
# Current Close:  8958.0
# Check between 4923.0    8958.0
# Check between 2491.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-09 /////////////////////
# RSI 2.3404580583730237
# MACD 10
# EMA DIFF 5.0
# Bollinger Bands 0
# Stochastic Value 2.0555121003105086
# CF Value 0.0
# ##################################### Results =  19.395970158683532 %
# ------------------------------------------------ 630
# 2019-12-10, Close: 9190.00
# macd 331.89823328059447   Signal 273.1618825101291
# rsi 75.88266757288572
# short EMA 8504.492356050258
# long EMA 8172.594122769663
# Bollinger Top 9002.803012831379   Bollinger Bottom 7475.996987168621
# Stochastic K 84.288224704357   Stochastic D: 69.12570084397026
# today Short EMA: 8504.492356050258 Long EMA: 8172.594122769663 Diff:  331.89823328059447
# -1 th Day Short EMA: 8379.85460260485 Long EMA: 8091.201652591236 Diff 288.6529500136139
# -2 th Day Short EMA: 8274.737257623914 Long EMA: 8021.857784798534 Diff 252.8794728253797
# -3 th Day Short EMA: 8216.689486282809 Long EMA: 7976.0864075824165 Diff 240.60307870039196
# -4 th Day Short EMA: 8198.269392879683 Long EMA: 7948.733320189011 Diff 249.53607269067288
# @STOCH, stoch comparison: 0
# 2019-06-10 00:00:00 2019-12-10 00:00:00
# 2018-12-10 00:00:00 2019-06-09 00:00:00
# 2017-12-10 00:00:00 2018-12-09 00:00:00
# Current Close:  9190.0
# Check between 5009.0    9190.0
# Check between 2491.0    5042.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-10 /////////////////////
# RSI 1.3724441423714282
# MACD 10
# EMA DIFF 7.5
# Bollinger Bands 0
# Stochastic Value 0.10168218509185678
# CF Value 0.0
# ##################################### Results =  18.974126327463285 %
# ------------------------------------------------ 631
# 2019-12-11, Close: 9474.00
# macd 384.6528200763132   Signal 295.4600700233659
# rsi 78.87558752537802
# short EMA 8653.647378196372
# long EMA 8268.994558120059
# Bollinger Top 9232.043123904521   Bollinger Bottom 7363.256876095478
# Stochastic K 88.31086668853003   Stochastic D: 81.07016889690449
# today Short EMA: 8653.647378196372 Long EMA: 8268.994558120059 Diff:  384.6528200763132
# -1 th Day Short EMA: 8504.492356050258 Long EMA: 8172.594122769663 Diff 331.89823328059447
# -2 th Day Short EMA: 8379.85460260485 Long EMA: 8091.201652591236 Diff 288.6529500136139
# -3 th Day Short EMA: 8274.737257623914 Long EMA: 8021.857784798534 Diff 252.8794728253797
# -4 th Day Short EMA: 8216.689486282809 Long EMA: 7976.0864075824165 Diff 240.60307870039196
# @STOCH, stoch comparison: 0
# 2019-06-11 00:00:00 2019-12-11 00:00:00
# 2018-12-11 00:00:00 2019-06-10 00:00:00
# 2017-12-11 00:00:00 2018-12-10 00:00:00
# Current Close:  9474.0
# Check between 5009.0    9474.0
# Check between 2491.0    5044.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-11 /////////////////////
# RSI 0.3748041582073256
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 0
# CF Value 0.0
# ##################################### Results =  20.374804158207326 %
# ------------------------------------------------ 632
# 2019-12-14, Close: 9539.00
# macd 426.78643856211784   Signal 321.7253437311163
# rsi 79.5025553505203
# short EMA 8789.855473858468
# long EMA 8363.06903529635
# Bollinger Top 9440.865907689813   Bollinger Bottom 7313.734092310186
# Stochastic K 86.26949729524426   Stochastic D: 86.28952956271043
# today Short EMA: 8789.855473858468 Long EMA: 8363.06903529635 Diff:  426.78643856211784
# -1 th Day Short EMA: 8653.647378196372 Long EMA: 8268.994558120059 Diff 384.6528200763132
# -2 th Day Short EMA: 8504.492356050258 Long EMA: 8172.594122769663 Diff 331.89823328059447
# -3 th Day Short EMA: 8379.85460260485 Long EMA: 8091.201652591236 Diff 288.6529500136139
# -4 th Day Short EMA: 8274.737257623914 Long EMA: 8021.857784798534 Diff 252.8794728253797
# @STOCH, stoch comparison: 10
# 2019-06-15 00:00:00 2019-12-14 00:00:00
# 2018-12-15 00:00:00 2019-06-12 00:00:00
# 2017-12-16 00:00:00 2018-12-12 00:00:00
# Current Close:  9539.0
# Check between 5009.0    9539.0
# Check between 2491.0    5417.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-14 /////////////////////
# RSI 0.16581488315990356
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 0
# Stochastic Value 10
# CF Value 0.0
# ##################################### Results =  30.165814883159904 %
# ------------------------------------------------ 633
# 2019-12-15, Close: 9422.00
# macd 445.600111865102   Signal 346.50029735791344
# rsi 75.17736803455827
# short EMA 8887.108477880241
# long EMA 8441.50836601514
# Bollinger Top 9556.75181259343   Bollinger Bottom 7384.448187406571
# Stochastic K 80.41007375488003   Stochastic D: 84.99681257955142
# today Short EMA: 8887.108477880241 Long EMA: 8441.50836601514 Diff:  445.600111865102
# -1 th Day Short EMA: 8789.855473858468 Long EMA: 8363.06903529635 Diff 426.78643856211784
# -2 th Day Short EMA: 8653.647378196372 Long EMA: 8268.994558120059 Diff 384.6528200763132
# -3 th Day Short EMA: 8504.492356050258 Long EMA: 8172.594122769663 Diff 331.89823328059447
# -4 th Day Short EMA: 8379.85460260485 Long EMA: 8091.201652591236 Diff 288.6529500136139
# @STOCH, stoch comparison: 10
# 2019-06-15 00:00:00 2019-12-15 00:00:00
# 2018-12-15 00:00:00 2019-06-12 00:00:00
# 2017-12-16 00:00:00 2018-12-12 00:00:00
# Current Close:  9422.0
# Check between 5009.0    9539.0
# Check between 2491.0    5417.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-15 /////////////////////
# RSI 1.607543988480579
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 1.2406351582812292
# Stochastic Value 10.655703749302853
# CF Value 0.20662251655629138
# ##################################### Results =  33.710505412620954 %
# ------------------------------------------------ 634
# 2019-12-16, Close: 9329.00
# macd 447.8433019245349   Signal 366.76889827123773
# rsi 71.83214971289232
# short EMA 8955.09178897559
# long EMA 8507.248487051054
# Bollinger Top 9644.701497168959   Bollinger Bottom 7453.89850283104
# Stochastic K 64.80178301845248   Stochastic D: 77.16045135619224
# today Short EMA: 8955.09178897559 Long EMA: 8507.248487051054 Diff:  447.8433019245349
# -1 th Day Short EMA: 8887.108477880241 Long EMA: 8441.50836601514 Diff 445.600111865102
# -2 th Day Short EMA: 8789.855473858468 Long EMA: 8363.06903529635 Diff 426.78643856211784
# -3 th Day Short EMA: 8653.647378196372 Long EMA: 8268.994558120059 Diff 384.6528200763132
# -4 th Day Short EMA: 8504.492356050258 Long EMA: 8172.594122769663 Diff 331.89823328059447
# @STOCH, stoch comparison: 10
# 2019-06-16 00:00:00 2019-12-16 00:00:00
# 2018-12-16 00:00:00 2019-06-15 00:00:00
# 2017-12-16 00:00:00 2018-12-15 00:00:00
# Current Close:  9329.0
# Check between 5009.0    9539.0
# Check between 2491.0    5504.0
# Check between 2015.0    3629.0
# //////////////// 2019-12-16 /////////////////////
# RSI 2.7226167623692277
# MACD 10
# EMA DIFF 10.0
# Bollinger Bands 2.882061947011046
# Stochastic Value 12.885459568792502
# CF Value 0.370860927152318
# ##################################### Results =  38.8609992053251 %
# Final Portfolio Value: 1000000.00

# %%
final = 0
def checkMacd(macd,signal, maxShare):
    if macd[0] > signal[0]:
        return maxShare
    else:
        return 0
    
def checkRsi(rsi, maxShare):
    if rsi > 80:
        return 0
    if rsi < 20:
        return maxShare
    share = maxShare/60
    return maxShare - share*(rsi-20)

def checkEmaDiff(short_ema, long_ema):
    value = 0
    print("today Short EMA:",short_ema[0], "Long EMA:",long_ema[0], "Diff: ", short_ema[0] - long_ema[0])
    for i in range(0,-4, -1):
        if short_ema[i] - long_ema[i] < 0:
            print(i,"th Day Short EMA:",short_ema[i], "Long EMA:",long_ema[i],"Diff",short_ema[i] - long_ema[i])
            return value
        elif short_ema[i] - long_ema[i] > short_ema[i-1] - long_ema[i-1]:
            print(i-1,"th Day Short EMA:",short_ema[i-1], "Long EMA:",long_ema[i-1],"Diff",short_ema[i-1] - long_ema[i-1])
            value += 2.5
        else:
            print(i-1,"th Day Short EMA:",short_ema[i-1], "Long EMA:",long_ema[i-1] ,"Diff",short_ema[i-1] - long_ema[i-1])
            return value
    return value

def checkBollinger(close, bollinger, maxShare):
    top = bollinger.lines.top[0]
    bottom = bollinger.lines.bot[0]
    if close[0] > top or close[0] < bottom:
        return 0
    share = maxShare/(top - bottom)
    return maxShare - share*(close[0] - bottom)

def checkStochastic(stoch, maxShare_comp, maxShare_relative):
    totalValue = 0
    if stoch.slowk[0] < stoch.slowd[0]:
        totalValue += maxShare_comp
    print("@STOCH, stoch comparison:", totalValue)
    if stoch.slowk[0] > 85:
        return totalValue
    if stoch.slowk[0] < 15:
        totalValue += maxShare_relative
        return totalValue
    share = maxShare_relative/70
    totalValue += maxShare_relative - share*(stoch.slowk[0] - 15)
    return totalValue
 
def checkDate(fromdate, currentdate):
    if currentdate < fromdate + pd.DateOffset(years=2):
        return False
    return True

def sliceDate(data,currentDay,freq, period):
    if 'm' in period:
        return data[currentDay-pd.DateOffset(months=freq):currentDay]
    if 'y' in period:
        return data[currentDay-pd.DateOffset(years=freq):currentDay]
    
def checkCF(close, day, firstMaxShare, secondMaxShare, thirdMaxShare):
    close.index = pd.to_datetime(close.index, format='%Y-%m-%d')
    diff_6_first = sliceDate(close, day,6, 'm')
    diff_6_second = sliceDate(close, day,1, 'y')[:sliceDate(close, day,6,'m' ).first_valid_index()-pd.DateOffset(days=1)]
    diff_1_year = sliceDate(close, day,2, 'y')[:sliceDate(close, day,1,'y' ).first_valid_index()-pd.DateOffset(days=1)]
    print(diff_6_first.index.min(), diff_6_first.index.max())
    print(diff_6_second.index.min(), diff_6_second.index.max())
    print(diff_1_year.index.min(), diff_1_year.index.max())
    diff_6_first_min = diff_6_first.min()
    diff_6_first_max = diff_6_first.max()
    diff_6_second_min = diff_6_second.min()
    diff_6_second_max = diff_6_second.max()
    diff_1_year_min = diff_1_year.min()
    diff_1_year_max = diff_1_year.max()
    totalValue = 0
    print("Current Close: ", close[day])
    print('Check between', diff_6_first_min,'  ', diff_6_first_max)
    if close.loc[day] >= diff_6_first_min and close.loc[day]<= diff_6_first_max:
        share = firstMaxShare/ (diff_6_first_max - diff_6_first_min)
        totalValue += firstMaxShare - share*(close[day] - diff_6_first_min)
    print('Check between', diff_6_second_min,'  ', diff_6_second_max)
    if close.loc[day] >= diff_6_second_min and close.loc[day] <= diff_6_second_max:
        share = secondMaxShare/ (diff_6_second_max - diff_6_second_min)
        totalValue += secondMaxShare - share*(close[day]-diff_6_second_min)
    print('Check between', diff_1_year_min,'  ', diff_1_year_max)
    if close[day] >= diff_1_year_min and close.loc[day] <= diff_1_year_max:
        share = thirdMaxShare/ (diff_1_year_max - diff_1_year_min)
        totalValue += thirdMaxShare - share*(close[day]-diff_1_year_min)
    return totalValue
    
def checkAll(macd, signal, short_ema, long_ema, rsi, bollinger, close, stoch, date):
    algoShares = {'macd':10,'emaDiff':10, 'rsi':20, 'bollinger':20, 'stochastic_comp':10, 'stochastic_relative':10, 'cf':20}
    rsiValue = checkRsi(rsi, algoShares['rsi'])
    macdValue = checkMacd(macd, signal, algoShares['macd'])
    emaDiffValue = checkEmaDiff(short_ema, long_ema)
    bollingerValue = checkBollinger(close, bollinger, algoShares['bollinger'])
    stochasticValue = checkStochastic(stoch, algoShares['stochastic_comp'], algoShares['stochastic_relative'])
    cfValue = checkCF(indexedClose, pd.Timestamp(date), 8, 7, 5)    
    print('////////////////',date,'/////////////////////')
    print("RSI", rsiValue)
    print("MACD",macdValue)
    print('EMA DIFF', emaDiffValue)
    print("Bollinger Bands", bollingerValue)
    print("Stochastic Value", stochasticValue)
    print("CF Value", cfValue)
    results = rsiValue + macdValue + emaDiffValue + bollingerValue + stochasticValue + cfValue
    print("##################################### Results = ", results,"%")
    return results

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('IranKhodro.csv',index_col='date')
data.index = pd.to_datetime(data.index, format='%Y%m%d', errors='ignore')
indexedClose = data.close
data['2017-12-20':'2017-12:31'][['close','open']]
# Out:
#              close    open
# date
# 2017-12-20  3098.0  3167.0
# 2017-12-23  3125.0  3098.0
# 2017-12-24  3196.0  3125.0
# 2017-12-25  3079.0  3196.0
# 2017-12-26  2993.0  3079.0
# 2017-12-27  2898.0  2993.0
# 2017-12-30  2791.0  2898.0
# 2017-12-31  2671.0  2791.0

# %%
# close = np.random.random(100)
# sma = tb.SMA(close)
# print(sma)
# from talib import MA_Type
# talib.get_functions()
from talib import STOCH
slowk, slowd = STOCH(data.high, data.low, data.close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
print(data.high.size)
# plt.figure(figsize=(25,17))
# plt.plot(slowk)
# plt.plot(slowd)
# plt.show()
# Out:
# 726

# %%
d = pd.read_csv('Iran.Khodro.csv', index_col=1, parse_dates=['<DTYYYYMMDD>'])
d = d[::-1]
d = d[["<OPEN>","<HIGH>","<LOW>","<CLOSE>","<VOL>","<VOL>"]]
d.columns = ["open","high","low","close","volume", 'volume']
d.to_csv('IranKhodro.csv')
d.head()
data = d

# %%
# data.index = pd.to_datetime(data.index, format='%Y-%m-%d')
# day = pd.Timestamp('2018-10-17')
# sliceDate(data, day,2, 'm')[:sliceDate(data, day,1,'m' ).first_valid_index()]
checkCF(data.close, pd.Timestamp('2017-10-10'), 8,7,5)
# data[pd.Timestamp('2017-10-10')-pd.Timedelta('1 m'):pd.Timestamp('2017-10-10')]
# Out:
# 2017-04-10 00:00:00 2017-10-10 00:00:00
# 2016-10-10 00:00:00 2017-04-09 00:00:00
# 2015-10-10 00:00:00 2016-10-09 00:00:00
# Current Close:  2441.0
# Check between 2356.0    2983.0
# Check between 2548.0    3507.0
# Check between 1477.0    4644.0
# 10.39352543600296
